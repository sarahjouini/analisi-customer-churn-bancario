# %%
import pandas as pd

bank = pd.read_csv("C:\\Users\\jouin\\Downloads\\archive (5)\\Bank Customer Churn Prediction.csv")
bank.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
bank["churn"].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
bank["churn"].value_counts(normalize=True) * 100
# Out:
# churn
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
bank.groupby("churn")["age"].mean()
# Out:
# churn
# 0    37.408389
# 1    44.837997
# Name: age, dtype: float64

# %%
bank.groupby("churn")["balance"].mean()
# Out:
# churn
# 0    72745.296779
# 1    91108.539337
# Name: balance, dtype: float64

# %%
bank.groupby("churn")["products_number"].mean()
# Out:
# churn
# 0    1.544267
# 1    1.475209
# Name: products_number, dtype: float64

# %%
bank.groupby("country")["churn"].mean()
# Out:
# country
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# Name: churn, dtype: float64
